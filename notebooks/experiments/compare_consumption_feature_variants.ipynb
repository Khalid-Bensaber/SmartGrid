# %% [markdown]
# # Comparaison rapide des variantes de features
#
# Ce notebook lit le CSV produit par `scripts/benchmark_feature_variants.py` et trie les runs par performance.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parents[1]
BENCHMARK_CSV = PROJECT_ROOT / "artifacts" / "benchmarks" / "consumption_feature_variants.csv"

df = pd.read_csv(BENCHMARK_CSV)

df.sort_values(["MAE", "RMSE"])
df
# Out:
#                                   config                            run_id  \
# 0  configs/consumption/mlp_baseline.yaml  consumption_mlp_20260410T035116Z
# 1  configs/consumption/mlp_cyclical.yaml  consumption_mlp_20260410T035130Z
#
#   selected_analysis_day  count           MAE          RMSE      Bias(ME)  \
# 0            2025-11-29   2620  18187.567062  28104.908480  -8630.563913
# 1            2025-11-29   2620  22958.373852  32534.424428 -12431.250641
#
#       MAPE%  InTolerance%   P95AbsError    P99AbsError  UnderShare%  \
# 0  6.867542     26.030534  62988.725000  103916.816406    62.290076
# 1  8.335430     18.854962  67814.404687  108354.958437    60.305344
#
#    OverShare%     Under_MAE      Over_MAE    SMAPE%  CorrAbsErr_vs_Real  \
# 0   37.709924  21526.808565  12671.734944  7.164242            0.376878
# 1   39.694656  29342.030434  13260.126352  8.742054            0.582222
#
#    RampingError_RMSE
# 0        6424.881564
# 1        6582.263721

# %%
cols = ["config", "MAE", "RMSE", "MAPE%", "SMAPE%", "Bias(ME)", "InTolerance%", "P95AbsError", "P99AbsError", "RampingError_RMSE"]
df[cols].sort_values(["MAE", "RMSE"])
# Out:
#                                   config           MAE          RMSE  \
# 0  configs/consumption/mlp_baseline.yaml  18187.567062  28104.908480
# 1  configs/consumption/mlp_cyclical.yaml  22958.373852  32534.424428
#
#       MAPE%    SMAPE%      Bias(ME)  InTolerance%   P95AbsError  \
# 0  6.867542  7.164242  -8630.563913     26.030534  62988.725000
# 1  8.335430  8.742054 -12431.250641     18.854962  67814.404687
#
#      P99AbsError  RampingError_RMSE
# 0  103916.816406        6424.881564
# 1  108354.958437        6582.263721

# %%
best = df.sort_values(["MAE", "RMSE"]).iloc[0]
best
# Out:
# config                   configs/consumption/mlp_baseline.yaml
# run_id                        consumption_mlp_20260410T035116Z
# selected_analysis_day                               2025-11-29
# count                                                     2620
# MAE                                               18187.567062
# RMSE                                               28104.90848
# Bias(ME)                                          -8630.563913
# MAPE%                                                 6.867542
# InTolerance%                                         26.030534
# P95AbsError                                          62988.725
# P99AbsError                                      103916.816406
# UnderShare%                                          62.290076
# OverShare%                                           37.709924
# Under_MAE                                         21526.808565
# Over_MAE                                          12671.734944
# SMAPE%                                                7.164242
# CorrAbsErr_vs_Real                                    0.376878
# RampingError_RMSE                                  6424.881564
# Name: 0, dtype: object
